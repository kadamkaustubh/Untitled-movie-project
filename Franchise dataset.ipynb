# %%
from imdb import IMDb
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
from bs4 import BeautifulSoup as bs

# %%
ia = IMDb(accessSystem='http', adultSearch=False)

# %%
html = 'http://www.boxofficemojo.com/franchises/?view=Franchise&p=.htm'
r = requests.get(html)  # Most sites can be accessed via the get function

# %%
page_source = r.content
page_soup = bs(page_source, "lxml")

# %%
print("The number of tables in the document is ", len(page_soup.find_all('table')) )
# Out:
# The number of tables in the document is  4

# %%
# Table attributes: table border="0" cellspacing="1" cellpadding="5" width="95%"
no_cell_space = len(page_soup.find_all('table', attrs={'cellspacing': '1'}))
print("The number of tables in the document with this cellspacing is ", no_cell_space)

no_cell_pad = len(page_soup.find_all('table', attrs={'cellpadding': '5'}))
print( "The number of tables in the document with this cellpadding is ", no_cell_pad)

no_border = len(page_soup.find_all('table', attrs={'border': '0'}))
print( "The number of tables in the document with this border is ", no_border)
# Out:
# The number of tables in the document with this cellspacing is  1
# The number of tables in the document with this cellpadding is  1
# The number of tables in the document with this border is  4

# %%
table = page_soup.find_all('table', attrs={'cellspacing': '1'})[0]

# %%
#check header row
data_row = table.find_all('tr')[0]
data_cols = data_row.find_all('td')  # List of columns in the first data row
for column in data_cols:
    print( column.text)  # Access the text in each column
# Out:
# Franchise (click to view chart)
# Total Gross
# # Movies / Average
# #1 Picture
# Gross

# %%
# Check data 
data_row = table.find_all('tr')[5]
data_cols = data_row.find_all('td')  # List of columns in the first data row
for column in data_cols:
    print( column.text)  # Access the text in each column
# Out:
# Alice in Wonderland
# $411.2
# 2
# $205.6
# Alice in Wonderland
# $334.2

# %%
# Set up the dictionary to save the data
output_columns = ['Franchise', 'Total Gross','Total Movies', 'Average Revenue', 'Top Movie', 'Top Gross']
output = dict((x, []) for x in output_columns)
#Ignore first row coz its the header row
all_rows = table.find_all('tr')[1:]
for row in all_rows:
    row_cols = row.find_all('td')
    # Loop through the columns and output keys to populate dictionary
    for dict_key, col in zip(output_columns, row_cols):
        output[dict_key].append(col.text)
        
# Put output into a DataFrame and rearrange columns in desired order
output_pd = pd.DataFrame(output)
output_pd = output_pd[output_columns]

# %%
# Get reference urls
output_columns = ['FranchiseID','MovieID']
IDoutput = dict((x, []) for x in output_columns)
#Ignore first row coz its the header row
all_rows = table.find_all('tr')[1:]
for row in all_rows:
    row_cols = row.find_all('a', href=True)
    # Loop through the columns and output keys to populate dictionary
    for dict_key, col in zip(output_columns, row_cols):
        IDoutput[dict_key].append(col['href'])
        
# Put output into a DataFrame and rearrange columns in desired order
IDoutput_pd = pd.DataFrame(IDoutput)
IDoutput_pd = IDoutput_pd[output_columns]

# %%
# Add ID columns
output_pd['FranchiseID']= IDoutput['FranchiseID']
output_pd['MovieID']= IDoutput['MovieID']

# %%
#Make numbers readable by Numpy
totalmovies=np.array(output_pd['Total Movies'],dtype=int)
A=output_pd['Total Gross']
for i in range(A.shape[0]):
    A[i]=A[i].strip('$')
    A[i]=A[i].replace(',','')
    A[i]=A[i].replace('k','e-3')    
totalgross=np.array(A,dtype=float)

A=output_pd['Average Revenue']
for i in range(A.shape[0]):
    A[i]=A[i].strip('$')
    A[i]=A[i].replace(',','')
    A[i]=A[i].replace('k','e-3')    
avgrev=np.array(A,dtype=float)

A=output_pd['Top Gross']
for i in range(A.shape[0]):
    A[i]=A[i].strip('$')
    A[i]=A[i].replace(',','')
    A[i]=A[i].replace('k','e-3')    
topgross=np.array(A,dtype=float)
A=output_pd['FranchiseID']
for i in range(A.shape[0]):
    A[i]=A[i].strip('.')    
output_pd['FranchiseID']=A
output_pd['Total Movies']=totalmovies
output_pd['Total Gross']=totalgross
output_pd['Average Revenue']=avgrev
output_pd['Top Gross']=topgross

# %%
df_pop=output_pd[output_pd['Average Revenue']>100]
df_pop=df_pop[df_pop['Total Movies']>1]

# %%
df_pop
# Out:
#                              Franchise  Total Gross  Total Movies  \
# 1                                  300        317.2             2
# 4                  Alice in Wonderland        411.2             2
# 6              Alvin and the Chipmunks        662.7             5
# 8                         American Pie        409.2             4
# 15                       Austin Powers        473.2             3
# 17                            Avengers       1755.3             3
# 18                  Back to the Future        416.8             3
# 19                            Bad Boys        204.4             2
# 23                              Batman       2407.7            11
# 27                   Beverly Hills Cop        431.0             3
# 32                              Bourne        801.0             5
# 34                     Captain America        844.5             3
# 36                                Cars        588.4             3
# 38            The Chronicles of Narnia        537.7             3
# 39   Cloudy with a Chance of Meatballs        244.7             2
# 42                       The Conjuring        426.2             4
# 43                    Crocodile Dundee        309.7             3
# 44                        Daddy's Home        254.4             2
# 45             The Dark Knight Trilogy       1186.8             3
# 47                DC Extended Universe       1588.1             5
# 48                            Deadpool        674.2             2
# 49                       Despicable Me       1220.2             4
# 52                            Die Hard        502.4             5
# 54     Disney Live Action Reimaginings       2169.1             9
# 55                           Divergent        347.3             3
# 66                      Fantastic Four        342.7             3
# 67            The Fast and the Furious       1516.8             8
# 68                        Fifty Shades        381.2             3
# 70                        Finding Nemo        826.0             2
# 71                             Fockers        593.9             3
# ..                                 ...          ...           ...
# 159                         Ocean's 11        542.5             4
# 167                         Paul Blart        217.4             2
# 170           Pirates of the Caribbean       1451.8             5
# 171              Pitch Perfect Trilogy        354.2             3
# 173     Planet of the Apes (2011-2017)        532.2             3
# 188                         Ride Along        226.2             2
# 190                                Rio        275.2             2
# 191                     Robert Langdon        385.3             3
# 195                          Rush Hour        507.5             3
# 196                   The Santa Clause        368.6             3
# 199                         Scooby-Doo        237.5             2
# 202                    Sherlock Holmes        395.9             2
# 204                              Shrek       1419.6             5
# 211        Snow White and the Huntsman        203.7             2
# 212                         Spider-Man       1912.9             6
# 214                          SpongeBob        248.4             2
# 216                          Star Trek       1401.0            13
# 217                          Star Wars       4215.1            11
# 218                Star Wars Anthology        740.3             2
# 222                           Superman       1139.5             7
# 223                              Taken        374.1             3
# 224                                Ted        300.3             2
# 226                         Terminator        608.7             5
# 228                               Thor        702.5             3
# 230                          Toy Story        883.4             4
# 231                       Transformers       1455.2             6
# 235                           Twilight       1363.5             5
# 236                        Unbreakable        233.3             2
# 245                          Wolverine        538.7             3
# 250                              X-Men       2355.3            11
#
#      Average Revenue                          Top Movie  Top Gross  \
# 1              158.6                                300      210.6
# 4              205.6                Alice in Wonderland      334.2
# 6              132.5          Alvin and the Chipmunks 2      219.6
# 8              102.3                     American Pie 2      145.1
# 15             157.7                         Goldmember      213.3
# 17             585.1             Avengers: Infinity War      672.9
# 18             138.9                 Back to the Future      210.6
# 19             102.2                        Bad Boys II      138.6
# 23             218.9                    The Dark Knight      533.3
# 27             143.7                  Beverly Hills Cop      234.8
# 32             160.2               The Bourne Ultimatum      227.5
# 34             281.5                  Captain America 3      408.1
# 36             196.1                               Cars      244.1
# 38             179.2           The Chronicles of Narnia      291.7
# 39             122.3  Cloudy with a Chance of Meatballs      124.9
# 42             106.6                      The Conjuring      137.4
# 43             103.2                   Crocodile Dundee      174.8
# 44             127.2                       Daddy's Home      150.4
# 45             395.6                    The Dark Knight      533.3
# 47             317.6                       Wonder Woman      412.6
# 48             337.1                           Deadpool      363.1
# 49             305.1                    Despicable Me 2      368.1
# 52             100.5              Live Free or Die Hard      134.5
# 54             241.0               Beauty and the Beast      504.0
# 55             115.8                          Divergent      150.9
# 66             114.2              Fantastic Four (2005)      154.7
# 67             189.6                          Furious 7      353.0
# 68             127.1               Fifty Shades of Grey      166.2
# 70             413.0                       Finding Dory      486.3
# 71             198.0                   Meet the Fockers      279.3
# ..               ...                                ...        ...
# 159            135.6                     Ocean's Eleven      183.4
# 167            108.7               Paul Blart: Mall Cop      146.3
# 170            290.4                   Dead Man's Chest      423.3
# 171            118.1                    Pitch Perfect 2      184.3
# 173            177.4     Dawn of the Planet of the Apes      208.5
# 188            113.1                         Ride Along      134.9
# 190            137.6                                Rio      143.6
# 191            128.4                  The Da Vinci Code      217.5
# 195            169.2                        Rush Hour 2      226.2
# 196            122.9                   The Santa Clause      144.8
# 199            118.8                         Scooby-Doo      153.3
# 202            197.9                    Sherlock Holmes      209.0
# 204            283.9                            Shrek 2      441.2
# 211            101.9        Snow White and the Huntsman      155.3
# 212            318.8                         Spider-Man      403.7
# 214            124.2                          SpongeBob      163.0
# 216            107.8                          Star Trek      257.7
# 217            383.2       Star Wars: The Force Awakens      936.7
# 218            370.2                          Rogue One      532.2
